# %%
#Q1
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

print(df)

df['species'] = iris.target_names[iris.target]

sns.scatterplot(data=df, x="petal length (cm)", y="petal width (cm)", hue="species")

plt.title("Iris dataset scatter plot")
plt.show()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [raw]
# #Q2

# %%
new_df = pd.read_csv(r"/home/cslogin/mscii92/dataset/msc/student.csv")
new_df
# Out:
#        name  Percentage       Address     Education   age
# 0     anita        60.0       dhayari            ME   NaN
# 1     swati         NaN       kothrud     Msc(Chem)  22.0
# 2      amit        88.0       dhayari            MA  24.0
# 3     radha        55.0  shivajinagar     Msc(Chem)  19.0
# 4    atharv        78.0        pimpri           NaN  34.0
# 5    ritika        89.0        akurdi     MSc(Comp)  25.0
# 6  shailesh        89.0      kalewadi  Msc(Organic)  37.0
# 7   madhuri         NaN  neheru nagar     Msc(Chem)  32.0
# 8    pravin        67.0       dhayari     Msc(Chem)  21.0
# 9      Pihu        66.0          Pune     Bsc(Comp)  28.0

# %%
new_df.isna().count()
# Out:
# name          10
# Percentage    10
# Address       10
# Education     10
# age           10
# dtype: int64

# %%
df =new_df.dropna()
df
# Out:
#        name  Percentage       Address     Education   age
# 2      amit        88.0       dhayari            MA  24.0
# 3     radha        55.0  shivajinagar     Msc(Chem)  19.0
# 5    ritika        89.0        akurdi     MSc(Comp)  25.0
# 6  shailesh        89.0      kalewadi  Msc(Organic)  37.0
# 8    pravin        67.0       dhayari     Msc(Chem)  21.0
# 9      Pihu        66.0          Pune     Bsc(Comp)  28.0

# %%
#Q3

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
new_df['Education_encoded'] = le.fit_transform(new_df['Education'])
new_df
# Out:
#        name  Percentage       Address     Education   age  Education_encoded
# 0     anita        60.0       dhayari            ME   NaN                  2
# 1     swati         NaN       kothrud     Msc(Chem)  22.0                  4
# 2      amit        88.0       dhayari            MA  24.0                  1
# 3     radha        55.0  shivajinagar     Msc(Chem)  19.0                  4
# 4    atharv        78.0        pimpri           NaN  34.0                  6
# 5    ritika        89.0        akurdi     MSc(Comp)  25.0                  3
# 6  shailesh        89.0      kalewadi  Msc(Organic)  37.0                  5
# 7   madhuri         NaN  neheru nagar     Msc(Chem)  32.0                  4
# 8    pravin        67.0       dhayari     Msc(Chem)  21.0                  4
# 9      Pihu        66.0          Pune     Bsc(Comp)  28.0                  0

# %%
#Q4

# %%
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
 

iris = load_iris()
X = iris.data          
y = iris.target        
 
#Principle camponent analysis 
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)
 

X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.2, random_state=42)
 

model = LogisticRegression()
model.fit(X_train, y_train)
 

new_flower = [[6.1, 3.5, 7.4, 1.2]]              
new_flower_pca = pca.transform(new_flower)       
prediction = model.predict(new_flower_pca)
 

print("Predicted class:", iris.target_names[prediction[0]])
# Out:
# Predicted class: virginica
